# %%
import plotly_express as px
import json
import pandas as pd
import os
import glob

# %%
# 波动其情况
cw = pd.DataFrame.from_dict(json.load(open('all_algo_cw.json')))
cw.plot.line(grid=True,title="Month CW",figsize=(20,20),fontsize=20)

# %%
all_algo_cws = json.load(open('all_algo_cw.json'))
bandits = ["[Rmr, 'SZ500']", "[UP, 'SZ500']", "[EG, 'SZ500']", "[Pamr, 'SZ500']", "[Olmar, 'SZ500']", "[ONS, 'SZ500']",
           "[Rmr, 'SH500']", "[UP, 'SH500']", "[EG, 'SH500']", "[Pamr, 'SH500']", "[Olmar, 'SH500']", "[ONS, 'SH500']",
           "[Rmr, 'SH50']", "[UP, 'SH50']", "[EG, 'SH50']", "[Pamr, 'SH50']", "[Olmar, 'SH50']", "[ONS, 'SH50']",
           "[Rmr, 'ZZ100']", "[UP, 'ZZ100']", "[EG, 'ZZ100']", "[Pamr, 'ZZ100']", "[Olmar, 'ZZ100']","[ONS, 'ZZ100']","bandit"]
total_cws = {}
for key,cws in all_algo_cws.items():
    total = 1
    total_cws.setdefault(bandits[int(key)],[]).append(total)
    for cw in cws:
        total = total * cw
        total_cws.setdefault(bandits[int(key)],[]).append(total)
cw = pd.DataFrame.from_dict(total_cws)
cw.plot.line(grid=True,title="Month CW",figsize=(20,20),fontsize=20)

# %%
total_cws['bandit']
# Out:
# [1,
#  1.1558114232346202,
#  1.3252620169290121,
#  1.2347804736549193,
#  1.4492441384196462,
#  1.4261306645183238,
#  1.1727390868283012,
#  1.1592204827264476,
#  0.9976718381901021,
#  0.8379510343974167,
#  0.8516681490707244,
#  0.8389840216295296,
#  1.0244802918282012,
#  1.0941997535695194,
#  1.081932870012044,
#  1.006860686862373,
#  0.9888124098080181,
#  1.0416256190565403,
#  0.8244721015619554,
#  0.8112735475172753,
#  0.7109617558274942,
#  0.734339166923746,
#  0.6733570494113812,
#  0.5833181882856379,
#  0.5414744317722588,
#  0.49918683498800814,
#  0.5105953096645623,
#  0.506486811314073,
#  0.4836069966131949,
#  0.46008762976649253,
#  0.38404950284403316,
#  0.40937571330338524,
#  0.5511970394108853,
#  0.5671824364234258,
#  0.5510432549746789,
#  0.51471362139477,
#  0.4504788457285238,
#  0.5001615127619834,
#  0.5007318391418869,
#  0.6230040080335861,
#  0.597419766410085,
#  0.5631379067215664,
#  0.469138626468702,
#  0.2788915681012357,
#  0.2500241278901246,
#  0.2623034591026458,
#  0.2795545882287622,
#  0.3103853181738105,
#  0.327699610882739,
#  0.261154117762314,
#  0.2530030740879832,
#  0.29616754656911615,
#  0.25698272836744157,
#  0.20641683041344552,
#  0.19867179278989736,
#  0.19692988219416202,
#  0.199075641865173,
#  0.18748337256230016,
#  0.19435513478383976,
#  0.1955621042314488,
#  0.1778995743659559,
#  0.16480963989330247,
#  0.16716384142863405,
#  0.16804204049862198,
#  0.16075874109211874,
#  0.1666541895323221,
#  0.17660690110674154,
#  0.17864605207625733,
#  0.1633143116838521,
#  0.16809496902269785,
#  0.17226091413248518,
#  0.1737545749414169,
#  0.17672744381802707,
#  0.1837373332381111,
#  0.18189524012315705,
#  0.17170654974434502,
#  0.1656115419864055,
#  0.1606054726122415,
#  0.1480728995024585,
#  0.1470494220975315,
#  0.1416723898872163,
#  0.13952659545644316,
#  0.10131178451008502,
#  0.1008501912860927,
#  0.09418107363446211,
#  0.09440699750309661,
#  0.09899538251674622,
#  0.11660013259447151,
#  0.08503963662507366,
#  0.0823340759782621,
#  0.08723950303305575,
#  0.0888975254534558,
#  0.1061484717950145,
#  0.09987139649357196,
#  0.1189827172688605,
#  0.11464672389464474,
#  0.12486632980658212]

# %%
dir_path = 'result/algo/'
json_paths = glob.glob("result/algo/*")

# %%
json_paths
# Out:
# ['result/algo/SZ500.json',
#  'result/algo/last50.json',
#  'result/algo/SH50.json',
#  'result/algo/random.json',
#  'result/algo/SH500.json',
#  'result/algo/ZZ100.json']

# %%
SZ500 = pd.DataFrame.from_dict(json.load(open(json_paths[0])))
SZ500 = pd.DataFrame(SZ500.values.T, index=SZ500.columns, columns=['CORN', 'EG', 'Olmar', 'ONS', 'Pamr', 'Rmr', 'UP'])
print(SZ500.corr())
SZ500.plot.line(grid=True,title="{} YEAR CW".format(json_paths[0].split('/')[-1]),figsize=(20,20),fontsize=20)
# Out:
#            CORN        EG     Olmar       ONS      Pamr       Rmr        UP
# CORN   1.000000  0.999605  0.837886  0.755791  0.878695  0.540962  0.999539
# EG     0.999605  1.000000  0.843875  0.759272  0.887705  0.559044  0.999988
# Olmar  0.837886  0.843875  1.000000  0.808813  0.981288  0.335733  0.843762
# ONS    0.755791  0.759272  0.808813  1.000000  0.807018  0.371308  0.761715
# Pamr   0.878695  0.887705  0.981288  0.807018  1.000000  0.510223  0.887932
# Rmr    0.540962  0.559044  0.335733  0.371308  0.510223  1.000000  0.560995
# UP     0.999539  0.999988  0.843762  0.761715  0.887932  0.560995  1.000000

# %%
last50 = pd.DataFrame.from_dict(json.load(open(json_paths[1])))
last50 = pd.DataFrame(last50.values.T, index=last50.columns, columns=['CORN', 'EG', 'Olmar', 'ONS', 'Pamr', 'Rmr', 'UP'])
print(last50.corr())
last50.plot.line(grid=True,title="{} YEAR CW".format(json_paths[1].split('/')[-1]),figsize=(20,20),fontsize=20)
# Out:
#            CORN        EG     Olmar       ONS      Pamr       Rmr        UP
# CORN   1.000000  0.998974  0.716898  0.808746  0.877176  0.882260  0.998923
# EG     0.998974  1.000000  0.710911  0.805457  0.878223  0.881642  0.999988
# Olmar  0.716898  0.710911  1.000000  0.299653  0.838534  0.891669  0.709748
# ONS    0.808746  0.805457  0.299653  1.000000  0.683451  0.475051  0.805245
# Pamr   0.877176  0.878223  0.838534  0.683451  1.000000  0.834852  0.876780
# Rmr    0.882260  0.881642  0.891669  0.475051  0.834852  1.000000  0.881862
# UP     0.998923  0.999988  0.709748  0.805245  0.876780  0.881862  1.000000

# %%
SH50 = pd.DataFrame.from_dict(json.load(open(json_paths[2])))
SH50 = pd.DataFrame(SH50.values.T, index=SH50.columns, columns=['CORN', 'EG', 'Olmar', 'ONS', 'Pamr', 'Rmr', 'UP'])
print(SH50.corr())
SH50.plot.line(grid=True,title="{} YEAR CW".format(json_paths[2].split('/')[-1]),figsize=(20,20),fontsize=20)
# Out:
#            CORN        EG     Olmar       ONS      Pamr       Rmr        UP
# CORN   1.000000  0.998531  0.920854  0.729319  0.887318  0.811246  0.998467
# EG     0.998531  1.000000  0.939226  0.694312  0.889284  0.785281  0.999980
# Olmar  0.920854  0.939226  1.000000  0.435358  0.867351  0.570704  0.939708
# ONS    0.729319  0.694312  0.435358  1.000000  0.491996  0.976286  0.692823
# Pamr   0.887318  0.889284  0.867351  0.491996  1.000000  0.531942  0.890228
# Rmr    0.811246  0.785281  0.570704  0.976286  0.531942  1.000000  0.784030
# UP     0.998467  0.999980  0.939708  0.692823  0.890228  0.784030  1.000000

# %%
random = pd.DataFrame.from_dict(json.load(open(json_paths[3])))
random = pd.DataFrame(random.values.T, index=random.columns, columns=['CORN', 'EG', 'Olmar', 'ONS', 'Pamr', 'Rmr', 'UP'])
print(random.corr())
random.plot.line(grid=True,title="{} YEAR CW".format(json_paths[3].split('/')[-1]),figsize=(20,20),fontsize=20)
# Out:
#            CORN        EG     Olmar       ONS      Pamr       Rmr        UP
# CORN   1.000000  0.997107  0.076791  0.465053  0.440027 -0.155013  0.997382
# EG     0.997107  1.000000  0.113886  0.455113  0.475045 -0.174315  0.999982
# Olmar  0.076791  0.113886  1.000000 -0.052705  0.788752  0.438886  0.113689
# ONS    0.465053  0.455113 -0.052705  1.000000  0.288962 -0.451281  0.457932
# Pamr   0.440027  0.475045  0.788752  0.288962  1.000000  0.000466  0.474125
# Rmr   -0.155013 -0.174315  0.438886 -0.451281  0.000466  1.000000 -0.173750
# UP     0.997382  0.999982  0.113689  0.457932  0.474125 -0.173750  1.000000

# %%
SH500 = pd.DataFrame.from_dict(json.load(open(json_paths[4])))
SH500 = pd.DataFrame(SH500.values.T, index=SH500.columns, columns=['CORN', 'EG', 'Olmar', 'ONS', 'Pamr', 'Rmr', 'UP'])
print(SH500.corr())
SH500.plot.line(grid=True,title="{} YEAR CW".format(json_paths[4].split('/')[-1]),figsize=(20,20),fontsize=20)
# Out:
#            CORN        EG     Olmar       ONS      Pamr       Rmr        UP
# CORN   1.000000  0.999823  0.473180  0.832597  0.929523  0.472449  0.999775
# EG     0.999823  1.000000  0.483449  0.831798  0.931953  0.473818  0.999988
# Olmar  0.473180  0.483449  1.000000  0.408555  0.660694  0.663479  0.486231
# ONS    0.832597  0.831798  0.408555  1.000000  0.919289  0.611071  0.829719
# Pamr   0.929523  0.931953  0.660694  0.919289  1.000000  0.710554  0.931721
# Rmr    0.472449  0.473818  0.663479  0.611071  0.710554  1.000000  0.473961
# UP     0.999775  0.999988  0.486231  0.829719  0.931721  0.473961  1.000000

# %%
ZZ100 = pd.DataFrame.from_dict(json.load(open(json_paths[5])))
ZZ100 = pd.DataFrame(ZZ100.values.T, index=ZZ100.columns, columns=['CORN', 'EG', 'Olmar', 'ONS', 'Pamr', 'Rmr', 'UP'])
print(ZZ100.corr())
ZZ100.plot.line(grid=True,title="{} YEAR CW".format(json_paths[5].split('/')[-1]),figsize=(20,20),fontsize=20)
# Out:
#            CORN        EG     Olmar       ONS      Pamr       Rmr        UP
# CORN   1.000000  0.997567  0.241510  0.674766  0.865495  0.674331  0.997547
# EG     0.997567  1.000000  0.181851  0.637535  0.841332  0.622819  0.999982
# Olmar  0.241510  0.181851  1.000000  0.508131  0.588693  0.790712  0.179703
# ONS    0.674766  0.637535  0.508131  1.000000  0.854330  0.780048  0.639578
# Pamr   0.865495  0.841332  0.588693  0.854330  1.000000  0.809348  0.841157
# Rmr    0.674331  0.622819  0.790712  0.780048  0.809348  1.000000  0.622911
# UP     0.997547  0.999982  0.179703  0.639578  0.841157  0.622911  1.000000

# %%
# 相同算法不同数据集
datasets = [last50, SZ500, SH500, SH50, ZZ100,random]
names = ['last50', 'SZ500', 'SH500', 'SH50', 'ZZ100', 'random']
methods = ['CORN', 'EG', 'Olmar', 'ONS', 'Pamr', 'Rmr', 'UP']

# %%
for method in methods:
    df = pd.DataFrame()
    for dataset in datasets:
        df = pd.concat([df,dataset[method]],axis=1)
    print(df.corr())
    df.plot.line(grid=True,title="{} YEAR CW".format(method),figsize=(20,20),fontsize=20)
# Out:
#           CORN      CORN      CORN      CORN      CORN      CORN
# CORN  1.000000  0.567521  0.896067  0.516925  0.555902  0.950845
# CORN  0.567521  1.000000  0.918246  0.889201  0.958562  0.570654
# CORN  0.896067  0.918246  1.000000  0.806676  0.856976  0.933146
# CORN  0.516925  0.889201  0.806676  1.000000  0.983274  0.524399
# CORN  0.555902  0.958562  0.856976  0.983274  1.000000  0.560946
# CORN  0.950845  0.570654  0.933146  0.524399  0.560946  1.000000
#           EG        EG        EG        EG        EG        EG
# EG  1.000000  0.586331  0.894395  0.513390  0.565512  0.955366
# EG  0.586331  1.000000  0.925901  0.895545  0.949053  0.640058
# EG  0.894395  0.925901  1.000000  0.796047  0.845874  0.953285
# EG  0.513390  0.895545  0.796047  1.000000  0.991045  0.568473
# EG  0.565512  0.949053  0.845874  0.991045  1.000000  0.613914
# EG  0.955366  0.640058  0.953285  0.568473  0.613914  1.000000
#           Olmar     Olmar     Olmar     Olmar     Olmar     Olmar
# Olmar  1.000000  0.918465  0.564874  0.679994  0.578793  0.412215
# Olmar  0.918465  1.000000 -0.005016  0.638117  0.738302  0.368384
# Olmar  0.564874 -0.005016  1.000000 -0.005975  0.210827  0.414321
# Olmar  0.679994  0.638117 -0.005975  1.000000  0.036098 -0.135061
# Olmar  0.578793  0.738302  0.210827  0.036098  1.000000  0.723369
# Olmar  0.412215  0.368384  0.414321 -0.135061  0.723369  1.000000
#           ONS       ONS       ONS       ONS       ONS       ONS
# ONS  1.000000 -0.979000  0.229132 -0.162751 -0.250855  0.133053
# ONS -0.979000  1.000000  0.514962  0.932430  0.924383  0.437261
# ONS  0.229132  0.514962  1.000000  0.679420  0.679568  0.012048
# ONS -0.162751  0.932430  0.679420  1.000000  0.994881  0.243447
# ONS -0.250855  0.924383  0.679568  0.994881  1.000000  0.186072
# ONS  0.133053  0.437261  0.012048  0.243447  0.186072  1.000000
#           Pamr      Pamr      Pamr      Pamr      Pamr      Pamr
# Pamr  1.000000  0.858953  0.879558  0.668999  0.756554  0.699845
# Pamr  0.858953  1.000000  0.883646  0.471707  0.873350  0.289861
# Pamr  0.879558  0.883646  1.000000  0.589194  0.952938  0.800501
# Pamr  0.668999  0.471707  0.589194  1.000000  0.727225  0.668896
# Pamr  0.756554  0.873350  0.952938  0.727225  1.000000  0.812662
# Pamr  0.699845  0.289861  0.800501  0.668896  0.812662  1.000000
#           Rmr       Rmr       Rmr       Rmr       Rmr       Rmr
# Rmr  1.000000  0.883321  0.371442  0.519069  0.755873 -0.262849
# Rmr  0.883321  1.000000 -0.423026  0.421281  0.495595 -0.695332
# Rmr  0.371442 -0.423026  1.000000  0.179632  0.349170  0.425736
# Rmr  0.519069  0.421281  0.179632  1.000000  0.815327 -0.683289
# Rmr  0.755873  0.495595  0.349170  0.815327  1.000000 -0.326305
# Rmr -0.262849 -0.695332  0.425736 -0.683289 -0.326305  1.000000
#           UP        UP        UP        UP        UP        UP
# UP  1.000000  0.581265  0.896245  0.515822  0.563439  0.955118
# UP  0.581265  1.000000  0.927303  0.898143  0.949135  0.639297
# UP  0.896245  0.927303  1.000000  0.797958  0.845991  0.951967
# UP  0.515822  0.898143  0.797958  1.000000  0.991716  0.573661
# UP  0.563439  0.949135  0.845991  0.991716  1.000000  0.614799
# UP  0.955118  0.639297  0.951967  0.573661  0.614799  1.000000
